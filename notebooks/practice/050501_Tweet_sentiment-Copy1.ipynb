# %% [markdown]
# # Tweets

# %%
import sys
sys.path.append('/Users/efraflores/Desktop/hub/diplo/venv/lib/python3.9/site-packages')

# %% [markdown]
# ## Import

# %%
import os

BASE_DIR = '/Users/efraflores/Desktop/EF/Diplo/data/05'
FILE_NAME = '0505_tuit.csv'
print(os.listdir(BASE_DIR))
# Out:
# ['0501_cred.json', '0503_fraud.csv', 'tuit_model_supervised.pickle', '0505_profiles.csv', '.DS_Store', '0505_clusters.csv', 'tad_continous.csv', '0503_trans.csv', '0505_tuit.csv', 'ufo_discrete_model.pkl', '0503_holder.csv', 'ufo_continous_model.pkl', '0503_tad.csv', '0503_Xclustering.csv', '0503_city.csv', '0501_untitled.csv', 'tad_discrete.csv', 'tuit_model_unsupervised.pickle', 'ufo_sentim.csv', '0502_ufo_data.csv', '0505']

# %%
import pandas as pd
pd.options.display.float_format = '{:.4f}'.format

df = pd.read_csv(os.path.join(BASE_DIR,FILE_NAME),encoding='latin').set_index('tweet_id')
print(df.info())
df.sample()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132707 entries, 1027179935184703489 to 1025806323844300800
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   tweet_date_created  132707 non-null  object
#  1   tweet_text          132707 non-null  object
#  2   language            132707 non-null  object
#  3   sentiment           132707 non-null  object
#  4   sentiment_score     132707 non-null  object
# dtypes: object(5)
# memory usage: 6.1+ MB
# None
#                              tweet_date_created  \
# tweet_id
# 1021782240014073861  2018-07-24T15:40:44.861000
#
#                                                             tweet_text  \
# tweet_id
# 1021782240014073861  El @OL ha ofrecido por Yerry Mina, 40Millones...
#
#                     language sentiment  \
# tweet_id
# 1021782240014073861       es   NEUTRAL
#
#                                                        sentiment_score
# tweet_id
# 1021782240014073861  {"Neutral":0.924232304096221923828125,"Negativ...

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Timing and tone

# %%
import time
import numpy as np
from IPython.lib.display import Audio

start = time.time()
def time_exp(x):
    #Just print how many minutes and seconds have passed
    minutes, seconds = np.floor(x/60), 60*(x/60-np.floor(x/60))
    print(f"{'{:.0f}'.format(minutes)} minutos con {'{:.2f}'.format(seconds)} segundos")
    
def tone(a=1000, b=700, play_time_seconds=1, framerate=4410):
    #Make a sound! Useful while training models
    t = np.linspace(0, play_time_seconds, framerate*play_time_seconds)*np.pi
    return Audio(np.sin(a*t)+np.sin(b*t), rate=framerate, autoplay=True)

# %% [markdown]
# ### Clean tweet

# %%
'''!pip install bs4'''
import re, unicodedata
from bs4 import BeautifulSoup

def clean_tweet(text):
    # Obtenemos el texto:
    text = BeautifulSoup(unicodedata.normalize('NFD', text).encode('ascii', 'ignore'), "lxml").get_text()
    # Eliminación de las menciones en los tweets. Se excluyen los @ junto con todos los caracteres que le siguen (De la A a la Z, en minúsculas y mayusculas, y números del 0 al 9)
    text = re.sub(r"@[A-Za-z0-9]+", ' ', text)
    # Eliminación de las menciones en los tweets. Se excluyen los # junto con todos los caracteres que le siguen (De la A a la Z, en minúsculas y mayusculas, y números del 0 al 9)
    text = re.sub(r"#[A-Za-z0-9]+", ' ', text)
    # Eliminación de los links que inicien con https o http. Inicamos que la s es opcional (s?).
    text = re.sub(r"https?://[A-Za-z0-9./]+", ' ', text)
    # Eliminación de los links que inicien con www.
    text = re.sub(r"www.[A-Za-z0-9./]+", ' ', text)
    # Eliminación de todos los catacteres menos las letras y signos de puntuación. 
    text = re.sub(r"[^a-zA-Z]", ' ', text)
    #Elimina caracteres múltiples
    text = re.sub(r'(\S)\1*',r'\1',text)
    # Eliminamos espacios en blanco dobles.
    text = re.sub(r" +", ' ', text)
    return text.lower()

# %% [markdown]
# ### K-clusters

# %%
'''!pip install pygal'''
import pygal
from sklearn.cluster import KMeans
from sklearn.metrics import davies_bouldin_score, silhouette_score, silhouette_samples

def koptimo(df):
    sse,db,slc = {}, {}, {}
    for k in range(2, 16):
        kmeans = KMeans(n_clusters = k, max_iter= 100, random_state = 22).fit(df)
        if k == 3: labels = kmeans.labels_
        clusters = kmeans.labels_
        sse[k] = kmeans.inertia_ 
        db[k] = davies_bouldin_score(df, clusters)
        slc[k] = silhouette_score(df, clusters)

    dicts = [sse,db,slc]

    for dicc in dicts:
        min_value = min(list(dicc.values()))
        max_value = max(list(dicc.values()))
        for k in dicc.keys():
            dicc[k] = (dicc[k] - min_value + 1)/(max_value - min_value + 1)

    line_chart = pygal.Line()
    line_chart.title = 'K-óptimo'
    line_chart.x_labels = map(str, sse.keys())
    for name, dicc in zip(['Inertia','DB','Silhouette'],dicts):
        line_chart.add(name, list(map(lambda x: round(x,2), dicc.values())))
    display(line_chart)
    return line_chart

# %% [markdown]
# ### Clustering

# %%
'''!pip install seaborn'''
import string
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import MinMaxScaler

warnings.filterwarnings('ignore')

def clustering(df,
               cols,
               n_clusters=5,
               kmeans=False):
    df = df.copy()
    mm_df = MinMaxScaler()
    Xs = pd.DataFrame(mm_df.fit_transform(df[cols]), 
                      index = df.index,
                      columns = cols)
    
    cluster = (KMeans(n_clusters, random_state=22) if kmeans 
               else GaussianMixture(n_clusters, random_state=22))
    Xs['cluster'] = cluster.fit_predict(Xs)
    
    dict_cluster = dict(enumerate(string.ascii_uppercase[:n_clusters]))
    df['cluster'] = Xs['cluster'].map(dict_cluster) 
    print(f'Distribución de registros en los {n_clusters} clústeres')
    display(df['cluster'].value_counts(1).reset_index().sort_values(by='index'))

    pca = PCA(2)
    pipe_pca = Pipeline(steps=[('MinMax', mm_df),('PCA', pca)])
    Xg = pd.DataFrame(pipe_pca.fit_transform(df.iloc[:,:-1]), 
                      index = df.index,
                      columns = ['p1','p2'])
    Xg['cluster'] = df['cluster'].copy()
    print(f'Varianza explicada con 2dim: {"{:.1%}".format(pca.explained_variance_ratio_.sum())}')
    
    plt.figure(figsize=(10,6))
    sns.scatterplot(data=Xg.sort_values(by='cluster'),
                    x='p1',
                    y='p2',
                    alpha=0.5,
                    hue='cluster', 
                    palette = 'Paired')
    plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
    plt.show();
    
    return df,cluster

# %% [markdown]
# ### Profiles

# %%
def profiles(df,cols=None,cluster='cluster'):
    n_clusters = len(set(df[cluster]))
    
    if cols==None:
        cols=df.columns
        aux = df[cols].groupby(cluster).mean()
        #aux = aux.transpose()
        for col in aux.columns:
            aux[col] /= aux[col].sum()

        fig = plt.figure()
        fig, ax = plt.subplots(figsize=(int(n_clusters/1.5),max(1,int(len(aux.columns)/3))))
        fig.patch.set_facecolor('white')
        fig.patch.set_alpha(0.9)
        sns.heatmap(aux.transpose(),cmap='Blues')
        plt.show();
        
    else:
        for col in cols:
            aux = df.copy()
            aux['n'] = 1
            aux = aux.pivot_table(index=cluster,
                                  columns=col,
                                  values='n',
                                  aggfunc='count',
                                  fill_value=0)
            for columna in aux.columns:
                aux[columna] /= aux[columna].sum()

            fig = plt.figure()
            fig, ax = plt.subplots(figsize=(int(n_clusters/1.5),max(1,int(len(set(df[col]))/4))))
            fig.patch.set_facecolor('white')
            fig.patch.set_alpha(0.9)
            sns.heatmap(aux.transpose(), cmap = 'Blues')
            plt.show();

# %% [markdown]
# ## Transform

# %% [markdown]
# ### Outliers

# %%
#There are outliers in the title length
df['len'] = df['tweet_text'].str.split().str.len()
df['len'].describe([i/10 for i in range(0,10,2)]+[.05,.95])
# Out:
# count   132707.0000
# mean        23.1615
# std         11.2318
# min          1.0000
# 0%           1.0000
# 5%           9.0000
# 20%         13.0000
# 40%         18.0000
# 50%         20.0000
# 60%         24.0000
# 80%         33.0000
# 95%         45.0000
# max         94.0000
# Name: len, dtype: float64

# %%
import numpy as np

df = df[(df['len'] < np.percentile(df['len'],98))& 
        (df['len'] > np.percentile(df['len'],2))].copy()
df['len'].describe([i/10 for i in range(0,10,2)])
# Out:
# count   125664.0000
# mean        23.0198
# std         10.1775
# min          9.0000
# 0%           9.0000
# 20%         14.0000
# 40%         18.0000
# 50%         21.0000
# 60%         24.0000
# 80%         32.0000
# max         49.0000
# Name: len, dtype: float64

# %% [markdown]
# ### Clean tweet

# %%
df['clean_tweet'] = df['tweet_text'].apply(clean_tweet)
df.sample(2)
# Out:
#                              tweet_date_created  \
# tweet_id
# 1016986728601718784  2018-07-11T10:05:05.784000
# 1041021744876797954  2018-09-15T17:51:39.954000
#
#                                                             tweet_text  \
# tweet_id
# 1016986728601718784  @TributoAlFutbol @_CHELOpy Hazard es del @Chel...
# 1041021744876797954  .@ManCity no tuvo que emplearse a fondo para i...
#
#                     language sentiment  \
# tweet_id
# 1016986728601718784       es   NEUTRAL
# 1041021744876797954       es   NEUTRAL
#
#                                                        sentiment_score  len  \
# tweet_id
# 1016986728601718784  {"Neutral":0.644622743129730224609375,"Negativ...   12
# 1041021744876797954  {"Neutral":0.715809881687164306640625,"Negativ...   15
#
#                                                            clean_tweet
# tweet_id
# 1016986728601718784       chelopy hazard es del y del chelsea no se va
# 1041021744876797954   no tuvo que emplearse a fondo para imponerse ...

# %%
df.loc[1035912630307835910,:]
# Out:
# tweet_date_created                           2018-09-01T15:29:52.910000
# tweet_text            #LigaPremierTD Al 71´Gooooooool del @ChelseaFC...
# language                                                             es
# sentiment                                                       NEUTRAL
# sentiment_score       {"Neutral":0.95787942409515380859375,"Negative...
# len                                                                  15
# clean_tweet               al gol del aparecio pedro y abre el marcador
# Name: 1035912630307835910, dtype: object

# %% [markdown]
# ### Variables

# %%
#All hashtags or mentions
df['#_or_@'] = df['tweet_text'].apply(lambda x: ' '.join(re.findall(r'[@|#]([\S]+)',x)))
#Split them like "VamosAmerica" to "vamos america", "UFC" stands the same
df['#_or_@'] = df['#_or_@'].apply(lambda x:re.sub(r'([A-Z])(?![A-Z])',lambda a:' '+a.group(1).lower(),x).strip())

df['length'] = df['tweet_text'].apply(len)
df['relevance'] = df['clean_tweet'].apply(len)/(df['length']+1e-10)

df['n_mentions'] = df['tweet_text'].apply(lambda x: len(re.findall('@',x)))
df['n_hashtags'] = df['tweet_text'].apply(lambda x: len(re.findall('#',x)))
df['n_links'] = df['tweet_text'].apply(lambda x: len(re.findall('http',x)))
df['n_uppercase'] = df['tweet_text'].apply(lambda x: len(re.findall('[A-Z]',x)))

df['p_mentions'] = df['n_mentions'] / df['len']
df['p_hashtags'] = df['n_hashtags'] / df['len']
df['p_links'] = df['n_links'] / df['len']
df['p_uppercase'] = df['n_uppercase'] /df['length']

df['n_len_p_word'] = df['length'] / df['len']
df['lpw_clean'] = df['clean_tweet'].apply(len) / df['len']

df['tot_text'] = df['#_or_@']+" "+df['clean_tweet']

backup = df.copy()
df.sample()
# Out:
#                              tweet_date_created  \
# tweet_id
# 1024550547079061504  2018-08-01T07:01:00.504000
#
#                                                             tweet_text  \
# tweet_id
# 1024550547079061504  ???\n\n?? ¡¡¡Día de partido!!!\n\n? @LCFC\n?? ...
#
#                     language sentiment  \
# tweet_id
# 1024550547079061504       es   NEUTRAL
#
#                                                        sentiment_score  len  \
# tweet_id
# 1024550547079061504  {"Neutral":0.91444051265716552734375,"Negative...   25
#
#                                                        clean_tweet  \
# tweet_id
# 1024550547079061504   dia de partido king power stadium cet media
#
#                                                                 #_or_@  \
# tweet_id
# 1024550547079061504  LCF c  gol apunt_media ?  leicester valencia V...
#
#                      length  relevance  ...  n_hashtags  n_links  n_uppercase  \
# tweet_id                                ...
# 1024550547079061504     223     0.2018  ...           4        3           30
#
#                      p_mentions  p_hashtags  p_links  p_uppercase  \
# tweet_id
# 1024550547079061504      0.1200      0.1600   0.1200       0.1345
#
#                      n_len_p_word  lpw_clean  \
# tweet_id
# 1024550547079061504        8.9200     1.8000
#
#                                                               tot_text
# tweet_id
# 1024550547079061504  LCF c  gol apunt_media ?  leicester valencia V...
#
# [1 rows x 21 columns]

# %%
num = df.head().describe().columns.tolist()
X = df.reset_index().set_index(['tweet_id','tot_text'])[num].copy()
X = X.reset_index().set_index('tweet_id').copy()
X.sample()
# Out:
#                                                               tot_text  len  \
# tweet_id
# 1022563249366200321  manchester united chao barca yery mina tendria...   14
#
#                      length  relevance  n_mentions  n_hashtags  n_links  \
# tweet_id
# 1022563249366200321     141     0.5035           0           1        2
#
#                      n_uppercase  p_mentions  p_hashtags  p_links  \
# tweet_id
# 1022563249366200321           13      0.0000      0.0714   0.1429
#
#                      p_uppercase  n_len_p_word  lpw_clean
# tweet_id
# 1022563249366200321       0.0922       10.0714     5.0714

# %%
X.columns
# Out:
# Index(['tot_text', 'len', 'length', 'relevance', 'n_mentions', 'n_hashtags',
#        'n_links', 'n_uppercase', 'p_mentions', 'p_hashtags', 'p_links',
#        'p_uppercase', 'n_len_p_word', 'lpw_clean'],
#       dtype='object')

# %% [markdown]
# ## Supervised

# %% [markdown]
# ### Preprocessing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,df['sentiment'].values,
                                                    train_size=0.77,
                                                    random_state=22)
print(X_test.shape)
# Out:
# (28903, 14)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_extraction.text import TfidfVectorizer

mm_x = MinMaxScaler()

tv = TfidfVectorizer(ngram_range=(1,3), 
                     min_df=10, 
                     max_features=1000)

prep = ColumnTransformer(transformers=[('Scale', mm_x, num), 
                                       ('CountV', tv, 'tot_text')])

# %% [markdown]
# ### LogReg

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(n_jobs=-1)
model_logreg = Pipeline(steps=[('preproc', prep),
                               ('model', logreg)])

model_logreg.fit(X_train,y_train).score(X_test,y_test)
# Out:
# 0.8744420994360447

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier 
forest = RandomForestClassifier(n_jobs=-1)

param_forest = {'n_estimators': [x for x in range(1400, 1500, 30)],
                'max_features': ['auto', 'sqrt', 'log2'],
                'criterion': ['gini', 'entropy'],
                'class_weight': ['balanced', None],
                'min_samples_split': [x for x in range(10, 22,3)],
                'min_samples_leaf': [x/100 for x in range(1, 6,2)]
               }

from sklearn.model_selection import RandomizedSearchCV
search_forest = RandomizedSearchCV(param_distributions = param_forest, 
                                   cv = 4, 
                                   n_jobs = -1, 
                                   scoring = 'accuracy',
                                   estimator = forest,
                                   verbose = 5,
                                   n_iter = 30,
                                   random_state = 22)

model_forest = Pipeline(steps=[('preproc', prep),
                               ('model', search_forest)])

model_forest.fit(X_train,y_train).score(X_test,y_test)
# Out:
# Fitting 4 folds for each of 30 candidates, totalling 120 fits
# 0.8449641905684531

# %% [markdown]
# ### Confussion Matrix

# %%
from sklearn.metrics import confusion_matrix
model = model_logreg
pd.DataFrame(confusion_matrix(y_test,model.predict(X_test))).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_f8173_row0_col0,#T_f8173_row1_col1,#T_f8173_row2_col2,#T_f8173_row3_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_f8173_row0_col1,#T_f8173_row0_col2,#T_f8173_row0_col3,#T_f8173_row1_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_f8173_row1_col2{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_f8173_row1_col3{
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }#T_f8173_row2_col0{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_f8173_row2_col1{
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }#T_f8173_row2_col3{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_f8173_row3_col0{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_f8173_row3_col1{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_f8173_row3_col2{
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }</style><table id="T_f8173_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f8173_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f8173_row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_f8173_row0_col1" class="data row0 col1" >36</td>
#                         <td id="T_f8173_row0_col2" class="data row0 col2" >58</td>
#                         <td id="T_f8173_row0_col3" class="data row0 col3" >31</td>
#             </tr>
#             <tr>
#                         <th id="T_f8173_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f8173_row1_col0" class="data row1 col0" >5</td>
#                         <td id="T_f8173_row1_col1" class="data row1 col1" >565</td>
#                         <td id="T_f8173_row1_col2" class="data row1 col2" >1333</td>
#                         <td id="T_f8173_row1_col3" class="data row1 col3" >105</td>
#             </tr>
#             <tr>
#                         <th id="T_f8173_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f8173_row2_col0" class="data row2 col0" >8</td>
#                         <td id="T_f8173_row2_col1" class="data row2 col1" >238</td>
#                         <td id="T_f8173_row2_col2" class="data row2 col2" >23827</td>
#                         <td id="T_f8173_row2_col3" class="data row2 col3" >349</td>
#             </tr>
#             <tr>
#                         <th id="T_f8173_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f8173_row3_col0" class="data row3 col0" >11</td>
#                         <td id="T_f8173_row3_col1" class="data row3 col1" >62</td>
#                         <td id="T_f8173_row3_col2" class="data row3 col2" >1393</td>
#                         <td id="T_f8173_row3_col3" class="data row3 col3" >859</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Save supervised

# %%
import pickle
with open(os.path.join(BASE_DIR,'tuit_model_supervised.pickle'), 'wb') as f:
    pickle.dump(model, f)

# %% [markdown]
# ## Unsupervised

# %%
df = df.join(pd.DataFrame(df['sentiment_score'].apply(eval).tolist(),index=df.index))
df.sample(4)
# Out:
#                              tweet_date_created  \
# tweet_id
# 1023549966671900675  2018-07-29T12:45:03.675000
# 1023647539147538432  2018-07-29T19:12:46.432000
# 1041315412863057921  2018-09-16T13:18:35.921000
# 1028241717017882624  2018-08-11T11:28:23.624000
#
#                                                             tweet_text  \
# tweet_id
# 1023549966671900675  #Fútbol @ChelseaFC pide 226,6 millones de dóla...
# 1023647539147538432  @ChelseaFC @AlvaroMorata Felicidades crack!. B...
# 1041315412863057921  #PremierLeague || Flojo primer tiempo entre #W...
# 1028241717017882624  Por fín #Fútbol de verdad\n#Newcastle - #Totte...
#
#                     language sentiment  \
# tweet_id
# 1023549966671900675       es   NEUTRAL
# 1023647539147538432       es  POSITIVE
# 1041315412863057921       es  NEGATIVE
# 1028241717017882624       es   NEUTRAL
#
#                                                        sentiment_score  len  \
# tweet_id
# 1023549966671900675  {"Neutral":0.96309661865234375,"Negative":0.01...   14
# 1023647539147538432  {"Neutral":0.04865454137325286865234375,"Negat...   10
# 1041315412863057921  {"Neutral":0.21794153749942779541015625,"Negat...   17
# 1028241717017882624  {"Neutral":0.87245595455169677734375,"Negative...    9
#
#                                                            clean_tweet  \
# tweet_id
# 1023549966671900675         pide milones de dolares por los pagara el
# 1023647539147538432    felicidades crack bendiciones eternas para los
# 1041315412863057921   flojo primer tiempo entre y se van al descans...
# 1028241717017882624                                 por fin de verdad
#
#                                                                 #_or_@  \
# tweet_id
# 1023549966671900675    fútbol  chelseaF c  hazard eden10  real madrid?
# 1023647539147538432                          chelseaF c  alvaro morata
# 1041315412863057921  premier league |  wolverhampton  burnleyF c. W...
# 1028241717017882624       fútbol  newcastle  tottenham  premier league
#
#                      length  relevance  ...  p_hashtags  p_links  p_uppercase  \
# tweet_id                                ...
# 1023549966671900675     119     0.3613  ...      0.0714   0.0714       0.1261
# 1023647539147538432      78     0.6154  ...      0.0000   0.0000       0.0897
# 1041315412863057921     135     0.4296  ...      0.2353   0.0588       0.1333
# 1028241717017882624      64     0.2812  ...      0.4444   0.0000       0.0938
#
#                      n_len_p_word  lpw_clean  \
# tweet_id
# 1023549966671900675        8.5000     3.0714
# 1023647539147538432        7.8000     4.8000
# 1041315412863057921        7.9412     3.4118
# 1028241717017882624        7.1111     2.0000
#
#                                                               tot_text  \
# tweet_id
# 1023549966671900675  fútbol  chelseaF c  hazard eden10  real madrid...
# 1023647539147538432  chelseaF c  alvaro morata  felicidades crack b...
# 1041315412863057921  premier league |  wolverhampton  burnleyF c. W...
# 1028241717017882624  fútbol  newcastle  tottenham  premier league p...
#
#                      Neutral  Negative  Positive  Mixed
# tweet_id
# 1023549966671900675   0.9631    0.0154    0.0165 0.0051
# 1023647539147538432   0.0487    0.0025    0.9334 0.0154
# 1041315412863057921   0.2179    0.6794    0.0399 0.0628
# 1028241717017882624   0.8725    0.0315    0.0867 0.0094
#
# [4 rows x 25 columns]

# %% [markdown]
# ### K-clusters

# %%
X_unsup = df[df.head().describe().columns].copy()
X_unsup.sample()
# Out:
#                     len  length  relevance  n_mentions  n_hashtags  n_links  \
# tweet_id
# 992526748876267520   29     219     0.1735           3           5        1
#
#                     n_uppercase  p_mentions  p_hashtags  p_links  p_uppercase  \
# tweet_id
# 992526748876267520           39      0.1034      0.1724   0.0345       0.1781
#
#                     n_len_p_word  lpw_clean  Neutral  Negative  Positive  \
# tweet_id
# 992526748876267520        7.5517     1.3103   0.9173    0.0442    0.0290
#
#                     Mixed
# tweet_id
# 992526748876267520 0.0096

# %%
line_chart = koptimo(X_unsup.sample(frac=.01))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/Desktop/hub/diplo/venv/lib/python3.9/site-packages/pygal/graph/base.py in _repr_png_(self)
#     232     def _repr_png_(self):
#     233         """Display png in IPython notebook"""
# --> 234         return self.render_to_png()
#
# ~/Desktop/hub/diplo/venv/lib/python3.9/site-packages/pygal/graph/public.py in render_to_png(self, filename, dpi, **kwargs)
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#     117         """Render the graph, convert it to png and write it to filename"""
# --> 118         import cairosvg
#     119         return cairosvg.svg2png(
#     120             bytestring=self.render(**kwargs), write_to=filename, dpi=dpi)
#
# ModuleNotFoundError: No module named 'cairosvg'

# %%
line_chart.render_in_browser()
# Out:
# file:///var/folders/j4/1p33_bh96yn8pdz3b_5t80hm0000gn/T/tmpdw_sjapu.html

# %% [markdown]
# ### Clustering

# %%
X_cluster,cluster_model = clustering(X_unsup,X_unsup.columns,n_clusters=4)
# Out:
# Distribución de registros en los 4 clústeres
#   index  cluster
# 2     A   0.2231
# 3     B   0.1233
# 1     C   0.2419
# 0     D   0.4117
# Varianza explicada con 2dim: 59.9%

# %% [markdown]
# ### Profiles

# %%
X_cluster.groupby("cluster").mean().style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_c78d1_row0_col0,#T_c78d1_row0_col1,#T_c78d1_row0_col5,#T_c78d1_row1_col3,#T_c78d1_row1_col4,#T_c78d1_row1_col6,#T_c78d1_row1_col7,#T_c78d1_row1_col8,#T_c78d1_row1_col10,#T_c78d1_row1_col11,#T_c78d1_row1_col13,#T_c78d1_row2_col5,#T_c78d1_row2_col9,#T_c78d1_row3_col2,#T_c78d1_row3_col12,#T_c78d1_row3_col14,#T_c78d1_row3_col15,#T_c78d1_row3_col16{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_c78d1_row0_col2{
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }#T_c78d1_row0_col3,#T_c78d1_row0_col7,#T_c78d1_row1_col2,#T_c78d1_row1_col12,#T_c78d1_row1_col15,#T_c78d1_row2_col0,#T_c78d1_row2_col1,#T_c78d1_row2_col14,#T_c78d1_row2_col16,#T_c78d1_row3_col4,#T_c78d1_row3_col5,#T_c78d1_row3_col6,#T_c78d1_row3_col8,#T_c78d1_row3_col9,#T_c78d1_row3_col10,#T_c78d1_row3_col11,#T_c78d1_row3_col13{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_c78d1_row0_col4{
#             background-color:  #add0e6;
#             color:  #000000;
#         }#T_c78d1_row0_col6{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_c78d1_row0_col8{
#             background-color:  #d2e3f3;
#             color:  #000000;
#         }#T_c78d1_row0_col9{
#             background-color:  #6dafd7;
#             color:  #000000;
#         }#T_c78d1_row0_col10{
#             background-color:  #e2edf8;
#             color:  #000000;
#         }#T_c78d1_row0_col11{
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }#T_c78d1_row0_col12,#T_c78d1_row2_col13{
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }#T_c78d1_row0_col13{
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }#T_c78d1_row0_col14{
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }#T_c78d1_row0_col15{
#             background-color:  #81badb;
#             color:  #000000;
#         }#T_c78d1_row0_col16{
#             background-color:  #97c6df;
#             color:  #000000;
#         }#T_c78d1_row1_col0{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_c78d1_row1_col1{
#             background-color:  #3989c1;
#             color:  #000000;
#         }#T_c78d1_row1_col5{
#             background-color:  #1967ad;
#             color:  #f1f1f1;
#         }#T_c78d1_row1_col9,#T_c78d1_row2_col12{
#             background-color:  #4191c6;
#             color:  #000000;
#         }#T_c78d1_row1_col14{
#             background-color:  #cde0f1;
#             color:  #000000;
#         }#T_c78d1_row1_col16{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_c78d1_row2_col2{
#             background-color:  #95c5df;
#             color:  #000000;
#         }#T_c78d1_row2_col3{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_c78d1_row2_col4,#T_c78d1_row2_col6{
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }#T_c78d1_row2_col7{
#             background-color:  #539ecd;
#             color:  #000000;
#         }#T_c78d1_row2_col8{
#             background-color:  #aed1e7;
#             color:  #000000;
#         }#T_c78d1_row2_col10{
#             background-color:  #a6cee4;
#             color:  #000000;
#         }#T_c78d1_row2_col11{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_c78d1_row2_col15{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_c78d1_row3_col0{
#             background-color:  #9fcae1;
#             color:  #000000;
#         }#T_c78d1_row3_col1{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_c78d1_row3_col3{
#             background-color:  #69add5;
#             color:  #000000;
#         }#T_c78d1_row3_col7{
#             background-color:  #4493c7;
#             color:  #000000;
#         }</style><table id="T_c78d1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >len</th>        <th class="col_heading level0 col1" >length</th>        <th class="col_heading level0 col2" >relevance</th>        <th class="col_heading level0 col3" >n_mentions</th>        <th class="col_heading level0 col4" >n_hashtags</th>        <th class="col_heading level0 col5" >n_links</th>        <th class="col_heading level0 col6" >n_uppercase</th>        <th class="col_heading level0 col7" >p_mentions</th>        <th class="col_heading level0 col8" >p_hashtags</th>        <th class="col_heading level0 col9" >p_links</th>        <th class="col_heading level0 col10" >p_uppercase</th>        <th class="col_heading level0 col11" >n_len_p_word</th>        <th class="col_heading level0 col12" >lpw_clean</th>        <th class="col_heading level0 col13" >Neutral</th>        <th class="col_heading level0 col14" >Negative</th>        <th class="col_heading level0 col15" >Positive</th>        <th class="col_heading level0 col16" >Mixed</th>    </tr>    <tr>        <th class="index_name level0" >cluster</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c78d1_level0_row0" class="row_heading level0 row0" >A</th>
#                         <td id="T_c78d1_row0_col0" class="data row0 col0" >33.496468</td>
#                         <td id="T_c78d1_row0_col1" class="data row0 col1" >223.214041</td>
#                         <td id="T_c78d1_row0_col2" class="data row0 col2" >0.664400</td>
#                         <td id="T_c78d1_row0_col3" class="data row0 col3" >1.218928</td>
#                         <td id="T_c78d1_row0_col4" class="data row0 col4" >2.338470</td>
#                         <td id="T_c78d1_row0_col5" class="data row0 col5" >0.959546</td>
#                         <td id="T_c78d1_row0_col6" class="data row0 col6" >19.500357</td>
#                         <td id="T_c78d1_row0_col7" class="data row0 col7" >0.037713</td>
#                         <td id="T_c78d1_row0_col8" class="data row0 col8" >0.070499</td>
#                         <td id="T_c78d1_row0_col9" class="data row0 col9" >0.030743</td>
#                         <td id="T_c78d1_row0_col10" class="data row0 col10" >0.088126</td>
#                         <td id="T_c78d1_row0_col11" class="data row0 col11" >6.713206</td>
#                         <td id="T_c78d1_row0_col12" class="data row0 col12" >4.431332</td>
#                         <td id="T_c78d1_row0_col13" class="data row0 col13" >0.768806</td>
#                         <td id="T_c78d1_row0_col14" class="data row0 col14" >0.077772</td>
#                         <td id="T_c78d1_row0_col15" class="data row0 col15" >0.123704</td>
#                         <td id="T_c78d1_row0_col16" class="data row0 col16" >0.029717</td>
#             </tr>
#             <tr>
#                         <th id="T_c78d1_level0_row1" class="row_heading level0 row1" >B</th>
#                         <td id="T_c78d1_row1_col0" class="data row1 col0" >22.323784</td>
#                         <td id="T_c78d1_row1_col1" class="data row1 col1" >188.210543</td>
#                         <td id="T_c78d1_row1_col2" class="data row1 col2" >0.318500</td>
#                         <td id="T_c78d1_row1_col3" class="data row1 col3" >3.512518</td>
#                         <td id="T_c78d1_row1_col4" class="data row1 col4" >5.892373</td>
#                         <td id="T_c78d1_row1_col5" class="data row1 col5" >0.755904</td>
#                         <td id="T_c78d1_row1_col6" class="data row1 col6" >34.229062</td>

# %%
profiles(X_cluster)

# %% [markdown]
# ### Export

# %%
X_cluster.groupby("cluster").mean().to_csv(os.path.join(BASE_DIR,'0505_profiles.csv'))
X_cluster.to_csv(os.path.join(BASE_DIR,'0505_clusters.csv'))

# %%
import pickle

with open(os.path.join(BASE_DIR,'tuit_model_unsupervised.pickle'), 'wb') as f:
    pickle.dump(cluster_model, f)

# %% [markdown]
# ## End

# %%
time_exp(time.time()-start)
tone()
# Out:
# 22 minutos con 43.93 segundos
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
